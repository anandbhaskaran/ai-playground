# %%
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults
# Out:
# ---------------------------------------------------------------------------
# PydanticUserError                         Traceback (most recent call last)
# Cell In[6], line 5
#       3 import operator
#       4 from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
# ----> 5 from langchain_openai import ChatOpenAI
#       6 from langchain_community.tools.tavily_search import TavilySearchResults
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/langchain_openai/__init__.py:1
# ----> 1 from langchain_openai.chat_models import (
#       2     AzureChatOpenAI,
#       3     ChatOpenAI,
#       4 )
#       5 from langchain_openai.embeddings import (
#       6     AzureOpenAIEmbeddings,
#       7     OpenAIEmbeddings,
#       8 )
#       9 from langchain_openai.llms import AzureOpenAI, OpenAI
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/langchain_openai/chat_models/__init__.py:1
# ----> 1 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       2 from langchain_openai.chat_models.base import ChatOpenAI
#       4 __all__ = [
#       5     "ChatOpenAI",
#       6     "AzureChatOpenAI",
#       7 ]
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/langchain_openai/chat_models/azure.py:13
#      10 from langchain_core.pydantic_v1 import Field, SecretStr, root_validator
#      11 from langchain_core.utils import convert_to_secret_str, get_from_dict_or_env
# ---> 13 from langchain_openai.chat_models.base import BaseChatOpenAI
#      15 logger = logging.getLogger(__name__)
#      18 class AzureChatOpenAI(BaseChatOpenAI):
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:294
#     290     parsed: Optional[_DictOrPydantic]
#     291     parsing_error: Optional[BaseException]
# --> 294 class BaseChatOpenAI(BaseChatModel):
#     295     client: Any = Field(default=None, exclude=True)  #: :meta private:
#     296     async_client: Any = Field(default=None, exclude=True)  #: :meta private:
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_model_construction.py:202, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     199 if config_wrapper.frozen and '__hash__' not in namespace:
#     200     set_default_hash_func(cls, bases)
# --> 202 complete_model_class(
#     203     cls,
#     204     cls_name,
#     205     config_wrapper,
#     206     raise_errors=False,
#     207     types_namespace=types_namespace,
#     208     create_model_module=_create_model_module,
#     209 )
#     211 # If this is placed before the complete_model_class call above,
#     212 # the generic computed fields return type is set to PydanticUndefined
#     213 cls.model_computed_fields = {k: v.info for k, v in cls.__pydantic_decorators__.computed_fields.items()}
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_model_construction.py:539, in complete_model_class(cls, cls_name, config_wrapper, raise_errors, types_namespace, create_model_module)
#     536     return False
#     538 try:
# --> 539     schema = cls.__get_pydantic_core_schema__(cls, handler)
#     540 except PydanticUndefinedAnnotation as e:
#     541     if raise_errors:
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/main.py:626, in BaseModel.__get_pydantic_core_schema__(cls, source, handler)
#     623     if not cls.__pydantic_generic_metadata__['origin']:
#     624         return cls.__pydantic_core_schema__
# --> 626 return handler(source)
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_schema_generation_shared.py:82, in CallbackGetCoreSchemaHandler.__call__(self, source_type)
#      81 def __call__(self, source_type: Any, /) -> core_schema.CoreSchema:
# ---> 82     schema = self._handler(source_type)
#      83     ref = schema.get('ref')
#      84     if self._ref_mode == 'to-def':
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:502, in GenerateSchema.generate_schema(self, obj, from_dunder_get_core_schema)
#     499         schema = from_property
#     501 if schema is None:
# --> 502     schema = self._generate_schema_inner(obj)
#     504 metadata_js_function = _extract_get_pydantic_json_schema(obj, schema)
#     505 if metadata_js_function is not None:
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:753, in GenerateSchema._generate_schema_inner(self, obj)
#     751 if lenient_issubclass(obj, BaseModel):
#     752     with self.model_type_stack.push(obj):
# --> 753         return self._model_schema(obj)
#     755 if isinstance(obj, PydanticRecursiveRef):
#     756     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:580, in GenerateSchema._model_schema(self, cls)
#     568     model_schema = core_schema.model_schema(
#     569         cls,
#     570         inner_schema,
#    (...)
#     576         metadata=metadata,
#     577     )
#     578 else:
#     579     fields_schema: core_schema.CoreSchema = core_schema.model_fields_schema(
# --> 580         {k: self._generate_md_field_schema(k, v, decorators) for k, v in fields.items()},
#     581         computed_fields=[
#     582             self._computed_field_schema(d, decorators.field_serializers)
#     583             for d in computed_fields.values()
#     584         ],
#     585         extras_schema=extras_schema,
#     586         model_name=cls.__name__,
#     587     )
#     588     inner_schema = apply_validators(fields_schema, decorators.root_validators.values(), None)
#     589     new_inner_schema = define_expected_missing_refs(inner_schema, recursively_defined_type_refs())
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:916, in GenerateSchema._generate_md_field_schema(self, name, field_info, decorators)
#     909 def _generate_md_field_schema(
#     910     self,
#     911     name: str,
#     912     field_info: FieldInfo,
#     913     decorators: DecoratorInfos,
#     914 ) -> core_schema.ModelField:
#     915     """Prepare a ModelField to represent a model field."""
# --> 916     common_field = self._common_field_schema(name, field_info, decorators)
#     917     return core_schema.model_field(
#     918         common_field['schema'],
#     919         serialization_exclude=common_field['serialization_exclude'],
#    (...)
#     923         metadata=common_field['metadata'],
#     924     )
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:1081, in GenerateSchema._common_field_schema(self, name, field_info, decorators)
#    1079         schema = self._apply_annotations(source_type, annotations, transform_inner_schema=set_discriminator)
#    1080     else:
# -> 1081         schema = self._apply_annotations(
#    1082             source_type,
#    1083             annotations,
#    1084         )
#    1086 # This V1 compatibility shim should eventually be removed
#    1087 # push down any `each_item=True` validators
#    1088 # note that this won't work for any Annotated types that get wrapped by a function validator
#    1089 # but that's okay because that didn't exist in V1
#    1090 this_field_validators = filter_field_decorator_info_by_field(decorators.validators.values(), name)
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:1825, in GenerateSchema._apply_annotations(self, source_type, annotations, transform_inner_schema)
#    1820         continue
#    1821     get_inner_schema = self._get_wrapped_inner_schema(
#    1822         get_inner_schema, annotation, pydantic_js_annotation_functions
#    1823     )
# -> 1825 schema = get_inner_schema(source_type)
#    1826 if pydantic_js_annotation_functions:
#    1827     metadata = CoreMetadataHandler(schema).metadata
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_schema_generation_shared.py:82, in CallbackGetCoreSchemaHandler.__call__(self, source_type)
#      81 def __call__(self, source_type: Any, /) -> core_schema.CoreSchema:
# ---> 82     schema = self._handler(source_type)
#      83     ref = schema.get('ref')
#      84     if self._ref_mode == 'to-def':
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:1806, in GenerateSchema._apply_annotations.<locals>.inner_handler(obj)
#    1804 from_property = self._generate_schema_from_property(obj, obj)
#    1805 if from_property is None:
# -> 1806     schema = self._generate_schema_inner(obj)
#    1807 else:
#    1808     schema = from_property
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:758, in GenerateSchema._generate_schema_inner(self, obj)
#     755 if isinstance(obj, PydanticRecursiveRef):
#     756     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# --> 758 return self.match_type(obj)
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:840, in GenerateSchema.match_type(self, obj)
#     838 origin = get_origin(obj)
#     839 if origin is not None:
# --> 840     return self._match_generic_type(obj, origin)
#     842 if self._arbitrary_types:
#     843     return self._arbitrary_type_schema(obj)
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:864, in GenerateSchema._match_generic_type(self, obj, origin)
#     861     return from_property
#     863 if _typing_extra.origin_is_union(origin):
# --> 864     return self._union_schema(obj)
#     865 elif origin in TUPLE_TYPES:
#     866     return self._tuple_schema(obj)
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:1152, in GenerateSchema._union_schema(self, union_type)
#    1150         nullable = True
#    1151     else:
# -> 1152         choices.append(self.generate_schema(arg))
#    1154 if len(choices) == 1:
#    1155     s = choices[0]
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:504, in GenerateSchema.generate_schema(self, obj, from_dunder_get_core_schema)
#     501 if schema is None:
#     502     schema = self._generate_schema_inner(obj)
# --> 504 metadata_js_function = _extract_get_pydantic_json_schema(obj, schema)
#     505 if metadata_js_function is not None:
#     506     metadata_schema = resolve_original_schema(schema, self.defs.definitions)
#
# File ~/Personal/coding/ai-playground/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2162, in _extract_get_pydantic_json_schema(tp, schema)
#    2160     if not has_custom_v2_modify_js_func:
#    2161         cls_name = getattr(tp, '__name__', None)
# -> 2162         raise PydanticUserError(
#    2163             f'The `__modify_schema__` method is not supported in Pydantic v2. '
#    2164             f'Use `__get_pydantic_json_schema__` instead{f" in class `{cls_name}`" if cls_name else ""}.',
#    2165             code='custom-json-schema',
#    2166         )
#    2168 # handle GenericAlias' but ignore Annotated which "lies" about its origin (in this case it would be `int`)
#    2169 if hasattr(tp, '__origin__') and not isinstance(tp, type(Annotated[int, 'placeholder'])):
#
# PydanticUserError: The `__modify_schema__` method is not supported in Pydantic v2. Use `__get_pydantic_json_schema__` instead in class `SecretStr`.
#
# For further information visit https://errors.pydantic.dev/2.7/u/custom-json-schema

# %%
tool = TavilySearchResults(max_results=4)
print(type(tool))
print(tool.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tool = TavilySearchResults(max_results=4)
#       2 print(type(tool))
#       3 print(tool.name)
#
# NameError: name 'TavilySearchResults' is not defined
